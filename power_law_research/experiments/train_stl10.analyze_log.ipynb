# %% [markdown]
# ## CSVLogger のメトリクスログを解析・ matplotlib でグラフ化

# %%
import glob

csv_logdir = "../log/stl10/clamp100/trial=*/gamma=*/csv"
metrics_files = sorted(glob.glob(f"{csv_logdir}/**/metrics.csv", recursive=True))
metrics_files
# Out:
# ['../log/stl10/clamp100/trial=0/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.0/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.1/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.2/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.30000000000000004/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.4/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.5/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.6000000000000001/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.7000000000000001/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.8/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=0.9/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.0/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.1/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.2000000000000002/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.3/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.4000000000000001/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.5/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.6/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.7000000000000002/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.8/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=0/gamma=1.9000000000000001/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.0/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.1/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.2/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.30000000000000004/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.4/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.5/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.6000000000000001/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.7000000000000001/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.8/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=0.9/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.0/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.1/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.2000000000000002/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.3/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.4000000000000001/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.5/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.6/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.7000000000000002/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.8/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=1/gamma=1.9000000000000001/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=2/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=2/gamma=0.0/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=2/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=2/gamma=0.1/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=2/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=2/gamma=0.2/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=2/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=2/gamma=0.30000000000000004/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=2/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=2/gamma=0.4/csv/lightning_logs/version_1/metrics.csv',
#  '../log/stl10/clamp100/trial=2/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/stl10/clamp100/trial=2/gamma=0.5/csv/lightning_logs/version_1/metrics.csv']

# %%
def metrics_parser(metrics_path):
    trial_str, gamma_str = metrics_path.split("/")[-6], metrics_path.split("/")[-5]
    trial = int(trial_str.replace("trial=", ""))
    gamma = float(gamma_str.replace("gamma=", ""))
    gamma = round(gamma, 3)
    return trial, gamma

# %%
import pandas as pd

metrics_path = metrics_files[0]
trial, gamma = metrics_parser(metrics_path)
df = pd.read_csv(metrics_path)
df
# Out:
#     train_recon_loss  train_kl  train_loss  epoch  step  val_recon_loss  \
# 0           0.910187  0.021479    0.931666      0    49             NaN
# 1           0.707397  0.018263    0.725660      0    99             NaN
# 2           0.657885  0.019461    0.677346      0   149             NaN
# 3           0.625624  0.020698    0.646322      0   199             NaN
# 4           0.564286  0.021934    0.586220      0   249             NaN
# 5           0.515157  0.023613    0.538770      0   299             NaN
# 6           0.617864  0.022753    0.640617      0   349             NaN
# 7           0.584378  0.025241    0.609619      0   399             NaN
# 8           0.483163  0.026137    0.509300      0   449             NaN
# 9           0.608784  0.027181    0.635965      0   499             NaN
# 10          0.479796  0.028126    0.507922      0   549             NaN
# 11          0.474784  0.027776    0.502560      0   599             NaN
# 12          0.440604  0.030194    0.470798      0   649             NaN
# 13          0.460107  0.029723    0.489831      0   699             NaN
# 14          0.459399  0.029046    0.488445      0   749             NaN
# 15          0.440246  0.028175    0.468421      0   799             NaN
# 16          0.479733  0.029933    0.509666      0   849             NaN
# 17          0.438721  0.031359    0.470081      0   899             NaN
# 18          0.575995  0.030328    0.606323      0   949             NaN
# 19          0.416021  0.031984    0.448005      0   999             NaN
# 20          0.422650  0.029721    0.452371      0  1049             NaN
# 21          0.484574  0.031641    0.516215      0  1099             NaN
# 22          0.441785  0.031599    0.473384      0  1149             NaN
# 23          0.415173  0.031035    0.446208      0  1199             NaN
# 24          0.452333  0.031062    0.483394      0  1249             NaN
# 25          0.387280  0.030702    0.417982      0  1299             NaN
# 26          0.423737  0.032799    0.456536      0  1349             NaN
# 27          0.361364  0.032205    0.393570      0  1399             NaN
# 28          0.389653  0.031941    0.421593      0  1449             NaN
# 29          0.431342  0.031271    0.462613      0  1499             NaN
# 30          0.426497  0.031082    0.457579      0  1549             NaN
# 31          0.413179  0.029290    0.442469      0  1599             NaN
# 32          0.455948  0.030678    0.486627      0  1649             NaN
# 33          0.394117  0.031358    0.425475      0  1699             NaN
# 34          0.425249  0.030305    0.455555      0  1749             NaN
# 35          0.418470  0.031850    0.450320      0  1799             NaN
# 36          0.381461  0.030728    0.412189      0  1849             NaN
# 37          0.387689  0.031472    0.419161      0  1899             NaN
# 38          0.342781  0.029744    0.372525      0  1949             NaN
# 39          0.400580  0.030822    0.431402      0  1999             NaN
# 40          0.385742  0.030200    0.415942      0  2049             NaN
# 41          0.424068  0.030664    0.454731      0  2099             NaN
# 42          0.468060  0.030464    0.498523      0  2149             NaN
# 43          0.413818  0.030317    0.444135      0  2199             NaN
# 44          0.386905  0.030772    0.417676      0  2249             NaN
# 45          0.390084  0.031658    0.421742      0  2299             NaN
# 46          0.372883  0.030714    0.403596      0  2349             NaN
# 47          0.363087  0.031194    0.394281      0  2399             NaN
# 48          0.331081  0.030170    0.361251      0  2449             NaN
# 49          0.356339  0.031455    0.387795      0  2499             NaN
# 50          0.341836  0.030501    0.372337      0  2549             NaN
# 51          0.434545  0.030481    0.465026      0  2599             NaN
# 52          0.351262  0.030447    0.381709      0  2649             NaN
# 53          0.337273  0.031117    0.368390      0  2699             NaN
# 54          0.392104  0.030518    0.422622      0  2749             NaN
# 55          0.370434  0.030938    0.401371      0  2799             NaN
# 56          0.381046  0.031205    0.412251      0  2849             NaN
# 57          0.398029  0.029953    0.427983      0  2899             NaN
# 58          0.347327  0.030882    0.378209      0  2949             NaN
# 59               NaN       NaN         NaN      0  2968        0.355161
#
#       val_kl  val_loss
# 0        NaN       NaN
# 1        NaN       NaN
# 2        NaN       NaN
# 3        NaN       NaN
# 4        NaN       NaN
# 5        NaN       NaN
# 6        NaN       NaN
# 7        NaN       NaN
# 8        NaN       NaN
# 9        NaN       NaN
# 10       NaN       NaN
# 11       NaN       NaN
# 12       NaN       NaN
# 13       NaN       NaN
# 14       NaN       NaN
# 15       NaN       NaN
# 16       NaN       NaN
# 17       NaN       NaN
# 18       NaN       NaN
# 19       NaN       NaN
# 20       NaN       NaN
# 21       NaN       NaN
# 22       NaN       NaN
# 23       NaN       NaN
# 24       NaN       NaN
# 25       NaN       NaN
# 26       NaN       NaN
# 27       NaN       NaN
# 28       NaN       NaN
# 29       NaN       NaN
# 30       NaN       NaN
# 31       NaN       NaN
# 32       NaN       NaN
# 33       NaN       NaN
# 34       NaN       NaN
# 35       NaN       NaN
# 36       NaN       NaN
# 37       NaN       NaN
# 38       NaN       NaN
# 39       NaN       NaN
# 40       NaN       NaN
# 41       NaN       NaN
# 42       NaN       NaN
# 43       NaN       NaN
# 44       NaN       NaN
# 45       NaN       NaN
# 46       NaN       NaN
# 47       NaN       NaN
# 48       NaN       NaN
# 49       NaN       NaN
# 50       NaN       NaN
# 51       NaN       NaN
# 52       NaN       NaN
# 53       NaN       NaN
# 54       NaN       NaN
# 55       NaN       NaN
# 56       NaN       NaN
# 57       NaN       NaN
# 58       NaN       NaN
# 59  0.032673  0.387834

# %%
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import pandas as pd

results = dict()
for path in tqdm(metrics_files):
    try:
        trial, gamma = metrics_parser(path)
        df = pd.read_csv(path)
        metrics = df.iloc[59]["val_loss"]
        # metrics = df.iloc[25]["val_recon_loss"]
        # metrics = df.iloc[25]["val_kl"]
        # metrics = df.iloc[0:25]['train_loss'].mean()
        # metrics = df.iloc[0:25]['train_recon_loss'].mean()
        # metrics = df.iloc[0:25]['train_kl'].mean()
        
        # gammaが辞書に存在しない場合は新たにキーを作成
        if gamma not in results:
            results[gamma] = []

        # 結果を辞書に追加
        results[gamma].append(metrics)
    except IndexError:
        continue
    
    

# エラーバーの計算
gammas = []
means = []
stds = []


for gamma, metrics in results.items():
    gammas.append(gamma)
    means.append(np.mean(metrics))
    stds.append(np.std(metrics))

# グラフの描画
plt.errorbar(gammas, means, yerr=stds, fmt='o', ecolor='r', capsize=2)
plt.xlabel('alpha')
plt.ylabel('Valid loss')
plt.title(r'Validation Loss v.s. $\alpha$')
plt.grid()
plt.show()
# Out:
# 100%|██████████| 92/92 [00:00<00:00, 765.00it/s]

# %%
results = dict()
for path in tqdm(metrics_files):
    try:
        trial, gamma = metrics_parser(path)
        df = pd.read_csv(path)
        # metrics = df.iloc[25]["val_loss"]
        metrics = df.iloc[59]["val_recon_loss"]
        # metrics = df.iloc[25]["val_kl"]
        # metrics = df.iloc[0:25]['train_loss'].mean()
        # metrics = df.iloc[0:25]['train_recon_loss'].mean()
        # metrics = df.iloc[0:25]['train_kl'].mean()
        
        # gammaが辞書に存在しない場合は新たにキーを作成
        if gamma not in results:
            results[gamma] = []

        # 結果を辞書に追加
        results[gamma].append(metrics)
    except IndexError:
        continue


# エラーバーの計算
gammas = []
means = []
stds = []


for gamma, metrics in results.items():
    gammas.append(gamma)
    means.append(np.mean(metrics))
    stds.append(np.std(metrics))

# グラフの描画
plt.errorbar(gammas, means, yerr=stds, fmt='o', ecolor='r', capsize=2)
plt.xlabel('alpha')
plt.ylabel('Valid recon loss')
plt.title(r'Validation Recon Loss v.s. $\alpha$')
plt.grid()
plt.show()
# Out:
# 100%|██████████| 92/92 [00:00<00:00, 820.12it/s]

# %%
results = dict()
for path in tqdm(metrics_files):
    try:
        trial, gamma = metrics_parser(path)
        df = pd.read_csv(path)
        # metrics = df.iloc[25]["val_loss"]
        # metrics = df.iloc[25]["val_recon_loss"]
        metrics = df.iloc[59]["val_kl"]
        # metrics = df.iloc[0:25]['train_loss'].mean()
        # metrics = df.iloc[0:25]['train_recon_loss'].mean()
        # metrics = df.iloc[0:25]['train_kl'].mean()
        
        # gammaが辞書に存在しない場合は新たにキーを作成
        if gamma not in results:
            results[gamma] = []

        # 結果を辞書に追加
        results[gamma].append(metrics)
    except IndexError:
        continue
    
    

# エラーバーの計算
gammas = []
means = []
stds = []


for gamma, metrics in results.items():
    gammas.append(gamma)
    means.append(np.mean(metrics))
    stds.append(np.std(metrics))

# グラフの描画
plt.errorbar(gammas, means, yerr=stds, fmt='o', ecolor='r', capsize=2)
plt.xlabel('alpha')
plt.ylabel('Valid KL loss')
plt.title(r'Validation KL Loss v.s. $\alpha$')
plt.grid()
plt.show()
# Out:
# 100%|██████████| 92/92 [00:00<00:00, 819.64it/s]

# %%
csv_logdir = "../log/scale_free_vae/gamma_zero_vanilla_vae/trial=*/gamma=*/csv"
metrics_files = sorted(glob.glob(f"{csv_logdir}/**/metrics.csv", recursive=True))

results = dict()
for path in tqdm(metrics_files):
    trial, gamma = metrics_parser(path)
    df = pd.read_csv(path)
    
    for key in ["val_loss", "val_recon_loss", "val_kl"]:
        if key not in results:
            results[key] = []
            
        metrics = df.iloc[59][key]
        results[key].append(metrics)
        
    for key in ["train_loss", "train_recon_loss", "train_kl"]:
        if key not in results:
            results[key] = []
        
        metrics = df.iloc[0:59][key]
        results[key].append(metrics)


for key, metrics in results.items():
    mean = np.mean(metrics)
    std = np.std(metrics)
    print(f"{key}: mean {mean} std {std}")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /workspaces/power-law-research/power_law_research/experiments/train_stl10.analyze_log.ipynb セル 8 line 1
#      <a href='vscode-notebook-cell://dev-container%...@ssh-remote%2Blocal-seki/workspaces/power-law-research/power_law_research/experiments/train_stl10.analyze_log.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>     if key not in results:
#      <a href='vscode-notebook-cell://dev-container%...@ssh-remote%2Blocal-seki/workspaces/power-law-research/power_law_research/experiments/train_stl10.analyze_log.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>         results[key] = []
# ---> <a href='vscode-notebook-cell://dev-container%...@ssh-remote%2Blocal-seki/workspaces/power-law-research/power_law_research/experiments/train_stl10.analyze_log.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     metrics = df.iloc[59][key]
#      <a href='vscode-notebook-cell://dev-container%...@ssh-remote%2Blocal-seki/workspaces/power-law-research/power_law_research/experiments/train_stl10.analyze_log.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>     results[key].append(metrics)
#      <a href='vscode-notebook-cell://dev-container%...@ssh-remote%2Blocal-seki/workspaces/power-law-research/power_law_research/experiments/train_stl10.analyze_log.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> for key in ["train_loss", "train_recon_loss", "train_kl"]:
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py:1625, in _iLocIndexer._getitem_axis(self, key, axis)
#    1622     raise TypeError("Cannot index by location index with a non-integer key")
#    1624 # validate the location
# -> 1625 self._validate_integer(key, axis)
#    1627 return self.obj._ixs(key, axis=axis)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py:1557, in _iLocIndexer._validate_integer(self, key, axis)
#    1555 len_axis = len(self.obj._get_axis(axis))
#    1556 if key >= len_axis or key < -len_axis:
# -> 1557     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# - `hparams.yaml` の中身:
#     ```yaml
#     lr: 0.01
#     n_hid: 100
#     n_vis: 784
#     normalize_loss: false
#     optimizer_name: sgd
#     power_law_gamma: 9.5
#     ```
# - `metrics.csv` の中身: logger に放り込んだ値がごちゃっと入っている
