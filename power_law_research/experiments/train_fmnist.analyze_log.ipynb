# %% [markdown]
# ## CSVLogger のメトリクスログを解析・ matplotlib でグラフ化

# %%
import glob

csv_logdir = "../log/fmnist/gamma_search_sgd_all_786/trial=*/gamma=*/csv"
metrics_files = sorted(glob.glob(f"{csv_logdir}/**/metrics.csv", recursive=True))
metrics_files
# Out:
# ['../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=0.0/csv/lightning_logs/version_1/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=0/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=1/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=10/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=11/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=12/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=13/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=14/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=15/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=16/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=17/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=18/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=19/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=2/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=3/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=4/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=5/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=6/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=7/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=8/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=0.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=0.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=0.2/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=0.30000000000000004/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=0.4/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=0.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=0.6000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=0.7000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=0.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=0.9/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=1.0/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=1.1/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=1.2000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=1.3/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=1.4000000000000001/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=1.5/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=1.6/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=1.7000000000000002/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=1.8/csv/lightning_logs/version_0/metrics.csv',
#  '../log/fmnist/gamma_search_sgd_all_786/trial=9/gamma=1.9000000000000001/csv/lightning_logs/version_0/metrics.csv']

# %%
def metrics_parser(metrics_path):
    trial_str, gamma_str = metrics_path.split("/")[-6], metrics_path.split("/")[-5]
    trial = int(trial_str.replace("trial=", ""))
    gamma = float(gamma_str.replace("gamma=", ""))
    gamma = round(gamma, 3)
    return trial, gamma

# %%
import pandas as pd

metrics_path = metrics_files[0]
trial, gamma = metrics_parser(metrics_path)
df = pd.read_csv(metrics_path)
df
# Out:
#     train_recon_loss   train_kl  train_loss  epoch  step  val_recon_loss  \
# 0           0.169792  13.619684   13.789475      0    49             NaN
# 1           0.174829  10.379066   10.553896      0    99             NaN
# 2           0.177765   5.931282    6.109046      0   149             NaN
# 3           0.169586   3.794078    3.963663      0   199             NaN
# 4           0.170822   3.842397    4.013219      0   249             NaN
# 5           0.168175   2.631203    2.799378      0   299             NaN
# 6           0.175728   2.949944    3.125672      0   349             NaN
# 7           0.163231   1.819711    1.982942      0   399             NaN
# 8           0.163540   1.518503    1.682043      0   449             NaN
# 9           0.176125   1.562136    1.738261      0   499             NaN
# 10          0.176000   1.210353    1.386353      0   549             NaN
# 11          0.165631   1.115109    1.280740      0   599             NaN
# 12          0.168199   0.914782    1.082981      0   649             NaN
# 13          0.163089   0.908446    1.071534      0   699             NaN
# 14          0.175969   1.306637    1.482606      0   749             NaN
# 15          0.178528   0.884055    1.062583      0   799             NaN
# 16          0.171995   0.615210    0.787205      0   849             NaN
# 17          0.183958   0.703982    0.887939      0   899             NaN
# 18          0.168853   0.667548    0.836401      0   949             NaN
# 19          0.170775   0.803681    0.974456      0   999             NaN
# 20          0.160083   0.499103    0.659186      0  1049             NaN
# 21          0.165723   0.395302    0.561025      0  1099             NaN
# 22          0.163059   0.574183    0.737242      0  1149             NaN
# 23          0.173300   0.766887    0.940187      0  1199             NaN
# 24          0.164416   0.481295    0.645711      0  1249             NaN
# 25          0.155900   0.263676    0.419576      0  1299             NaN
# 26          0.178465   0.453517    0.631982      0  1349             NaN
# 27          0.170461   0.234947    0.405408      0  1399             NaN
# 28          0.166826   0.312870    0.479696      0  1449             NaN
# 29          0.177695   0.540076    0.717771      0  1499             NaN
# 30               NaN        NaN         NaN      0  1499        0.170492
#
#       val_kl  val_loss
# 0        NaN       NaN
# 1        NaN       NaN
# 2        NaN       NaN
# 3        NaN       NaN
# 4        NaN       NaN
# 5        NaN       NaN
# 6        NaN       NaN
# 7        NaN       NaN
# 8        NaN       NaN
# 9        NaN       NaN
# 10       NaN       NaN
# 11       NaN       NaN
# 12       NaN       NaN
# 13       NaN       NaN
# 14       NaN       NaN
# 15       NaN       NaN
# 16       NaN       NaN
# 17       NaN       NaN
# 18       NaN       NaN
# 19       NaN       NaN
# 20       NaN       NaN
# 21       NaN       NaN
# 22       NaN       NaN
# 23       NaN       NaN
# 24       NaN       NaN
# 25       NaN       NaN
# 26       NaN       NaN
# 27       NaN       NaN
# 28       NaN       NaN
# 29       NaN       NaN
# 30  0.375045  0.545537

# %%
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import pandas as pd

results = dict()
for path in tqdm(metrics_files):
    try:
        trial, gamma = metrics_parser(path)
        df = pd.read_csv(path)
        metrics = df.iloc[30]["val_loss"]
        # metrics = df.iloc[25]["val_recon_loss"]
        # metrics = df.iloc[25]["val_kl"]
        # metrics = df.iloc[0:25]['train_loss'].mean()
        # metrics = df.iloc[0:25]['train_recon_loss'].mean()
        # metrics = df.iloc[0:25]['train_kl'].mean()
        
        # gammaが辞書に存在しない場合は新たにキーを作成
        if gamma not in results:
            results[gamma] = []

        # 結果を辞書に追加
        results[gamma].append(metrics)
    except IndexError:
        continue
    
    

# エラーバーの計算
gammas = []
means = []
stds = []


for gamma, metrics in results.items():
    gammas.append(gamma)
    means.append(np.mean(metrics))
    stds.append(np.std(metrics))

# グラフの描画
plt.errorbar(gammas, means, yerr=stds, fmt='o', ecolor='r', capsize=2)
plt.xlabel('alpha')
plt.ylabel('Valid loss')
plt.title(r'Validation Loss v.s. $\alpha$')
plt.grid()
plt.show()
# Out:
# 100%|██████████| 400/400 [00:00<00:00, 713.55it/s]

# %%
results = dict()
for path in tqdm(metrics_files):
    try:
        trial, gamma = metrics_parser(path)
        df = pd.read_csv(path)
        # metrics = df.iloc[25]["val_loss"]
        metrics = df.iloc[30]["val_recon_loss"]
        # metrics = df.iloc[25]["val_kl"]
        # metrics = df.iloc[0:25]['train_loss'].mean()
        # metrics = df.iloc[0:25]['train_recon_loss'].mean()
        # metrics = df.iloc[0:25]['train_kl'].mean()
        
        # gammaが辞書に存在しない場合は新たにキーを作成
        if gamma not in results:
            results[gamma] = []

        # 結果を辞書に追加
        results[gamma].append(metrics)
    except IndexError:
        continue


# エラーバーの計算
gammas = []
means = []
stds = []


for gamma, metrics in results.items():
    gammas.append(gamma)
    means.append(np.mean(metrics))
    stds.append(np.std(metrics))

# グラフの描画
plt.errorbar(gammas, means, yerr=stds, fmt='o', ecolor='r', capsize=2)
plt.xlabel('alpha')
plt.ylabel('Valid recon loss')
plt.title(r'Validation Recon Loss v.s. $\alpha$')
plt.grid()
plt.show()
# Out:
# 100%|██████████| 400/400 [00:00<00:00, 851.12it/s]

# %%
results = dict()
for path in tqdm(metrics_files):
    try:
        trial, gamma = metrics_parser(path)
        df = pd.read_csv(path)
        # metrics = df.iloc[25]["val_loss"]
        # metrics = df.iloc[25]["val_recon_loss"]
        metrics = df.iloc[30]["val_kl"]
        # metrics = df.iloc[0:25]['train_loss'].mean()
        # metrics = df.iloc[0:25]['train_recon_loss'].mean()
        # metrics = df.iloc[0:25]['train_kl'].mean()
        
        # gammaが辞書に存在しない場合は新たにキーを作成
        if gamma not in results:
            results[gamma] = []

        # 結果を辞書に追加
        results[gamma].append(metrics)
    except IndexError:
        continue
    
    

# エラーバーの計算
gammas = []
means = []
stds = []


for gamma, metrics in results.items():
    gammas.append(gamma)
    means.append(np.mean(metrics))
    stds.append(np.std(metrics))

# グラフの描画
plt.errorbar(gammas, means, yerr=stds, fmt='o', ecolor='r', capsize=2)
plt.xlabel('alpha')
plt.ylabel('Valid KL loss')
plt.title(r'Validation KL Loss v.s. $\alpha$')
plt.grid()
plt.show()
# Out:
# 100%|██████████| 400/400 [00:00<00:00, 839.56it/s]

# %%
csv_logdir = "../log/scale_free_vae/gamma_zero_vanilla_vae/trial=*/gamma=*/csv"
metrics_files = sorted(glob.glob(f"{csv_logdir}/**/metrics.csv", recursive=True))

results = dict()
for path in tqdm(metrics_files):
    trial, gamma = metrics_parser(path)
    df = pd.read_csv(path)
    
    for key in ["val_loss", "val_recon_loss", "val_kl"]:
        if key not in results:
            results[key] = []
            
        metrics = df.iloc[30][key]
        results[key].append(metrics)
        
    for key in ["train_loss", "train_recon_loss", "train_kl"]:
        if key not in results:
            results[key] = []
        
        metrics = df.iloc[0:30][key]
        results[key].append(metrics)


for key, metrics in results.items():
    mean = np.mean(metrics)
    std = np.std(metrics)
    print(f"{key}: mean {mean} std {std}")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /workspaces/power-law-research/power_law_research/experiments/train_fmnist.analyze_log.ipynb セル 8 line 1
#      <a href='vscode-notebook-cell://dev-container%...@ssh-remote%2Blocal-seki/workspaces/power-law-research/power_law_research/experiments/train_fmnist.analyze_log.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>     if key not in results:
#      <a href='vscode-notebook-cell://dev-container%...@ssh-remote%2Blocal-seki/workspaces/power-law-research/power_law_research/experiments/train_fmnist.analyze_log.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>         results[key] = []
# ---> <a href='vscode-notebook-cell://dev-container%...@ssh-remote%2Blocal-seki/workspaces/power-law-research/power_law_research/experiments/train_fmnist.analyze_log.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     metrics = df.iloc[30][key]
#      <a href='vscode-notebook-cell://dev-container%...@ssh-remote%2Blocal-seki/workspaces/power-law-research/power_law_research/experiments/train_fmnist.analyze_log.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>     results[key].append(metrics)
#      <a href='vscode-notebook-cell://dev-container%...@ssh-remote%2Blocal-seki/workspaces/power-law-research/power_law_research/experiments/train_fmnist.analyze_log.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> for key in ["train_loss", "train_recon_loss", "train_kl"]:
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py:1625, in _iLocIndexer._getitem_axis(self, key, axis)
#    1622     raise TypeError("Cannot index by location index with a non-integer key")
#    1624 # validate the location
# -> 1625 self._validate_integer(key, axis)
#    1627 return self.obj._ixs(key, axis=axis)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py:1557, in _iLocIndexer._validate_integer(self, key, axis)
#    1555 len_axis = len(self.obj._get_axis(axis))
#    1556 if key >= len_axis or key < -len_axis:
# -> 1557     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# - `hparams.yaml` の中身:
#     ```yaml
#     lr: 0.01
#     n_hid: 100
#     n_vis: 784
#     normalize_loss: false
#     optimizer_name: sgd
#     power_law_gamma: 9.5
#     ```
# - `metrics.csv` の中身: logger に放り込んだ値がごちゃっと入っている
